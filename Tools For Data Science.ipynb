# %% [markdown]
# <a href="https://colab.research.google.com/github/Sadcem/IBM-data-science-certification-projects/blob/main/Tools%20For%20Data%20Science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Hands-on Lab: Create your Jupyter Notebook

# %% [markdown]
# # Final Project - Data Science Tools and Ecosystem

# %% [markdown]
# This notebook is part of the final project for the IBM Data Science course. It covers basic concepts, tools, and practices used in data science.

# %% [markdown]
# ## Data Science Languages
# - Python
# - R
# - SQL
# - Julia
# - Scala

# %% [markdown]
# ## Data Science Libraries
# - Pandas
# - NumPy
# - Matplotlib
# - Scikit-learn
# - TensorFlow
# - ggplot2

# %% [markdown]
# ## Data Science Tools
#
# | Tool          | Category            |
# |---------------|---------------------|
# | Jupyter       | Notebook Interface  |
# | RStudio       | IDE                 |
# | Apache Spark  | Big Data Processing |
# | TensorFlow    | Machine Learning    |
# | Tableau       | Data Visualization  |

# %% [markdown]
# ## Arithmetic Expression Examples
# Below are examples of simple arithmetic operations using Python code.

# %%
# This expression multiplies 3 and 4, then adds 5
result = (3 * 4) + 5
print(result)
# Out:
# 17

# %%
# Convert 200 minutes to hours
minutes = 200
hours = minutes / 60
print(hours)
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Objectives
# - Learn popular languages used in data science
# - Understand common data science libraries and tools
# - Perform basic arithmetic operations using Python
# - Convert units using Python code
# - Use markdown effectively in Jupyter Notebooks

# %% [markdown]
# ## Author
# Sadeem Asiri

# %% [markdown]
# Copyright ©2024 IBM Corporation. All rights reserved.
